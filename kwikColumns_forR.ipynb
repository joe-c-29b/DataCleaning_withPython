# %%
import os
os.chdir("C:\\Users\jbcwi\OneDrive\Desktop\DataScienceMS\kaggle\housingPrices")

# %%
import pandas as pd
df = pd.read_csv('HP_columns.csv')
df
# Out:
#        Categories
# 0              Id
# 1      MSSubClass
# 2        MSZoning
# 3     LotFrontage
# 4         LotArea
# ..            ...
# 76         MoSold
# 77         YrSold
# 78       SaleType
# 79  SaleCondition
# 80      SalePrice
#
# [81 rows x 1 columns]

# %%
for i in df.Categories:
    print(f'table(is.na(HP.full${i}))')
# Out:
# table(is.na(HP.full$Id))
# table(is.na(HP.full$MSSubClass))
# table(is.na(HP.full$MSZoning))
# table(is.na(HP.full$LotFrontage))
# table(is.na(HP.full$LotArea))
# table(is.na(HP.full$Street))
# table(is.na(HP.full$Alley))
# table(is.na(HP.full$LotShape))
# table(is.na(HP.full$LandContour))
# table(is.na(HP.full$Utilities))
# table(is.na(HP.full$LotConfig))
# table(is.na(HP.full$LandSlope))
# table(is.na(HP.full$Neighborhood))
# table(is.na(HP.full$Condition1))
# table(is.na(HP.full$Condition2))
# table(is.na(HP.full$BldgType))
# table(is.na(HP.full$HouseStyle))
# table(is.na(HP.full$OverallQual))
# table(is.na(HP.full$OverallCond))
# table(is.na(HP.full$YearBuilt))
# table(is.na(HP.full$YearRemodAdd))
# table(is.na(HP.full$RoofStyle))
# table(is.na(HP.full$RoofMatl))
# table(is.na(HP.full$Exterior1st))
# table(is.na(HP.full$Exterior2nd))
# table(is.na(HP.full$MasVnrType))
# table(is.na(HP.full$MasVnrArea))
# table(is.na(HP.full$ExterQual))
# table(is.na(HP.full$ExterCond))
# ...
