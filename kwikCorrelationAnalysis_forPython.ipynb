# %%
import os
os.chdir("C:\\Users\jbcwi\OneDrive\Desktop\DataScienceMS\kaggle\housingPrices")

# %%
import pandas as pd
df = pd.read_csv('NHP.csv')
df
# Out:
#       SalePrice  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0      208500.0         6       1      0         1            1          1
# 1      181500.0         6       1      0         1            1          1
# 2      223500.0         6       1      0         2            1          1
# 3      140000.0         6       1      0         2            1          1
# 4      250000.0         6       1      0         2            1          1
# ...         ...       ...     ...    ...       ...          ...        ...
# 1455   175000.0         6       1      0         1            1          1
# 1456   210000.0         6       1      0         1            1          1
# 1457   266500.0         6       1      0         1            1          1
# 1458   142125.0         6       1      0         1            1          1
# 1459   147500.0         6       1      0         1            1          1
#
# ...

# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
import openpyxl
array = []
for col in df.columns:
    x = df[col]
    x1 = sm.add_constant(x, prepend = True)
    y = df['Exterior2nd']
    b = np.corrcoef(y,x)
    c = b[0,1].round(2)
    z = sm.OLS(y, x1).fit()
    a = z.pvalues[1]
    array.append([col, a, c])
output = pd.DataFrame(array, columns=['Category','P-value','Correlation'])
output.sort_values(by = ['Correlation'])
# Out:
#          Category        P-value  Correlation
# 3           Alley   1.259441e-02        -0.07
# 59   LowQualFinSF   6.936895e-02        -0.05
# 74  EnclosedPorch   6.767427e-02        -0.05
# 46    LotFrontage   5.366655e-02        -0.05
# 1        MSZoning   1.246483e-01        -0.04
# ..            ...            ...          ...
# 50      YearBuilt   1.712221e-07         0.14
# 38     PavedDrive   1.170593e-08         0.15
# 12       BldgType   1.764123e-09         0.16
# 16    Exterior1st  3.002857e-262         0.75
# 17    Exterior2nd   0.000000e+00         1.00
#
# [81 rows x 3 columns]

# %%
import numpy as np
for col in df.columns:
    x = df[col]
    y = df['SalePrice']
    z = np.corrcoef(x, y)
    a = z[0,1]
    if a > .5 and a < .8:
        print(f'meh: {col} : {a}')
    elif a > .8:
        print(f'good: {col} : {a}')

# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
import openpyxl
array = []
for col in df.columns:
    x = df[col]
    x1 = sm.add_constant(x, prepend = True)
    y = df['SalePrice']
    b = np.corrcoef(y,x)
    c = b[0,1].round(2)
    z = sm.OLS(y, x1).fit()
    a = z.pvalues[1]
    array.append([col, a, c])
output = pd.DataFrame(array, columns=['Category','P-value','Correlation'])
output.to_excel(r'HPcorrelations1.xlsx')

# %%
#OverallQual correlations

import statsmodels.api as sm
import numpy as np
import pandas as pd
import openpyxl
array = []
for col in df.columns:
    x = df[col]
    x1 = sm.add_constant(x, prepend = True)
    y = df['OverallQual']
    b = np.corrcoef(y,x)
    c = b[0,1].round(2)
    z = sm.OLS(y, x1).fit()
    a = z.pvalues[1]
    array.append([col, a, c])
output = pd.DataFrame(array, columns=['Category','P-value','Correlation'])
output.to_excel(r'HPcorrelations_OverallQual.xlsx')
#you must give a new file name anytime you want to rerun the output
# Out:
#        Category        P-value  Correlation
# 0     SalePrice  2.185675e-313         0.79
# 1      MSZoning   7.677501e-13        -0.19
# 2        Street   2.459838e-02         0.06
# 3         Alley   3.065143e-01        -0.03
# 4      LotShape   1.668462e-14         0.20
# ..          ...            ...          ...
# 76  ScreenPorch   1.314582e-02         0.06
# 77     PoolArea   1.275642e-02         0.07
# 78      MiscVal   2.304122e-01        -0.03
# 79       MoSold   6.790956e-03         0.07
# 80       YrSold   2.963852e-01        -0.03
#
# [81 rows x 3 columns]
